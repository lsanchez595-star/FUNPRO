# %%
def contador():
  notas=[]
  cantidad=int(input("cuantas notas componen el corte: "))
  for i in range(cantidad):
    nota=float(input(f"dijite sus notas:{i+1} "))
    notas.append(nota)
    print(notas)
  c=0
  for a in notas:
    if a>=3:
      c+=1
      print(f"van {c} notas")
  print(f"{c} notas fueron mayores o iguales a 3")
  return cantidad,notas

def promedio(notas,cantidad):
  total=sum(notas)
  promedio=total/cantidad
  print(f"su promedio es: {promedio}")

a,b=contador()
promedio(b,a)
# Out:
# cuantas notas componen el corte: 3
# dijite sus notas:1 4
# [4.0]
# dijite sus notas:2 5
# [4.0, 5.0]
# dijite sus notas:3 3
# [4.0, 5.0, 3.0]
# van 1 notas
# van 2 notas
# van 3 notas
# 3 notas fueron mayores o iguales a 3
# su promedio es: 4.0
